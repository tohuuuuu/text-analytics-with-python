# %%
import warnings
warnings.simplefilter("ignore", category=DeprecationWarning)
warnings.filterwarnings('ignore')

# %% [markdown]
# # Parts of Speech (POS) Tagging

# %%
sentence = "US unveils world's most powerful supercomputer, beats China."

import pandas as pd
import spacy
nlp = spacy.load('en_core_web_sm')
sentence_nlp = nlp(sentence)
# POS tagging with Spacy 
spacy_pos_tagged = [(word, word.tag_, word.pos_) for word in sentence_nlp]
pd.DataFrame(spacy_pos_tagged, columns=['Word', 'POS tag', 'Tag type']).T
# Out:
#              0        1      2     3     4         5              6      7   \
# Word         US  unveils  world    's  most  powerful  supercomputer      ,
# POS tag     NNP      VBZ     NN   POS   RBS        JJ             NN      ,
# Tag type  PROPN     VERB   NOUN  PART   ADV       ADJ           NOUN  PUNCT
#
#              8      9      10
# Word      beats  China      .
# POS tag     VBZ    NNP      .
# Tag type   VERB  PROPN  PUNCT

# %%
# POS tagging with nltk
import nltk
nltk_pos_tagged = nltk.pos_tag(nltk.word_tokenize(sentence))
pd.DataFrame(nltk_pos_tagged, columns=['Word', 'POS tag']).T
# Out:
#           0        1      2    3     4         5              6  7      8   \
# Word      US  unveils  world   's  most  powerful  supercomputer  ,  beats
# POS tag  NNP       JJ     NN  POS   RBS        JJ             NN  ,    VBZ
#
#             9  10
# Word     China  .
# POS tag    NNP  .

# %%
from nltk.corpus import treebank
data = treebank.tagged_sents()
train_data = data[:3500]
test_data = data[3500:]
print(train_data[0])
# Out:
# [('Pierre', 'NNP'), ('Vinken', 'NNP'), (',', ','), ('61', 'CD'), ('years', 'NNS'), ('old', 'JJ'), (',', ','), ('will', 'MD'), ('join', 'VB'), ('the', 'DT'), ('board', 'NN'), ('as', 'IN'), ('a', 'DT'), ('nonexecutive', 'JJ'), ('director', 'NN'), ('Nov.', 'NNP'), ('29', 'CD'), ('.', '.')]

# %%
# default tagger
from nltk.tag import DefaultTagger
dt = DefaultTagger('NN')

# %%
# accuracy on test data
dt.evaluate(test_data)
# Out:
# 0.1454158195372253

# %%
# tagging our sample headline
dt.tag(nltk.word_tokenize(sentence))
# Out:
# [('US', 'NN'),
#  ('unveils', 'NN'),
#  ('world', 'NN'),
#  ("'s", 'NN'),
#  ('most', 'NN'),
#  ('powerful', 'NN'),
#  ('supercomputer', 'NN'),
#  (',', 'NN'),
#  ('beats', 'NN'),
#  ('China', 'NN'),
#  ('.', 'NN')]

# %%
# regex tagger
from nltk.tag import RegexpTagger
# define regex tag patterns
patterns = [
        (r'.*ing$', 'VBG'),               # gerunds
        (r'.*ed$', 'VBD'),                # simple past
        (r'.*es$', 'VBZ'),                # 3rd singular present
        (r'.*ould$', 'MD'),               # modals
        (r'.*\'s$', 'NN$'),               # possessive nouns
        (r'.*s$', 'NNS'),                 # plural nouns
        (r'^-?[0-9]+(.[0-9]+)?$', 'CD'),  # cardinal numbers
        (r'.*', 'NN')                     # nouns (default) ... 
]
rt = RegexpTagger(patterns)

# %%
# accuracy on test data
rt.evaluate(test_data)
# Out:
# 0.24039113176493368

# %%
# tagging our sample headline
rt.tag(nltk.word_tokenize(sentence))
# Out:
# [('US', 'NN'),
#  ('unveils', 'NNS'),
#  ('world', 'NN'),
#  ("'s", 'NN$'),
#  ('most', 'NN'),
#  ('powerful', 'NN'),
#  ('supercomputer', 'NN'),
#  (',', 'NN'),
#  ('beats', 'NNS'),
#  ('China', 'NN'),
#  ('.', 'NN')]

# %%
## N gram taggers
from nltk.tag import UnigramTagger
from nltk.tag import BigramTagger
from nltk.tag import TrigramTagger

ut = UnigramTagger(train_data)
bt = BigramTagger(train_data)
tt = TrigramTagger(train_data)

# %%
# testing performance of unigram tagger
print(ut.evaluate(test_data))
print(ut.tag(nltk.word_tokenize(sentence)))
# Out:
# 0.8607803272340013
# [('US', 'NNP'), ('unveils', None), ('world', 'NN'), ("'s", 'POS'), ('most', 'JJS'), ('powerful', 'JJ'), ('supercomputer', 'NN'), (',', ','), ('beats', None), ('China', 'NNP'), ('.', '.')]

# %%
# testing performance of bigram tagger
print(bt.evaluate(test_data))
print(bt.tag(nltk.word_tokenize(sentence)))
# Out:
# 0.13466937748087907
# [('US', None), ('unveils', None), ('world', None), ("'s", None), ('most', None), ('powerful', None), ('supercomputer', None), (',', None), ('beats', None), ('China', None), ('.', None)]

# %%
# testing performance of trigram tagger
print(tt.evaluate(test_data))
print(tt.tag(nltk.word_tokenize(sentence)))
# Out:
# 0.08064672281924679
# [('US', None), ('unveils', None), ('world', None), ("'s", None), ('most', None), ('powerful', None), ('supercomputer', None), (',', None), ('beats', None), ('China', None), ('.', None)]

# %%
def combined_tagger(train_data, taggers, backoff=None):
    for tagger in taggers:
        backoff = tagger(train_data, backoff=backoff)
    return backoff

ct = combined_tagger(train_data=train_data, 
                     taggers=[UnigramTagger, BigramTagger, TrigramTagger],
                     backoff=rt)

# %%
# evaluating the new combined tagger with backoff taggers
print(ct.evaluate(test_data))      
print(ct.tag(nltk.word_tokenize(sentence)))
# Out:
# 0.9094781682641108
# [('US', 'NNP'), ('unveils', 'NNS'), ('world', 'NN'), ("'s", 'POS'), ('most', 'RBS'), ('powerful', 'JJ'), ('supercomputer', 'NN'), (',', ','), ('beats', 'NNS'), ('China', 'NNP'), ('.', '.')]

# %%
from nltk.classify import NaiveBayesClassifier, MaxentClassifier
from nltk.tag.sequential import ClassifierBasedPOSTagger

nbt = ClassifierBasedPOSTagger(train=train_data,
                               classifier_builder=NaiveBayesClassifier.train)

# %%
# evaluate tagger on test data and sample sentence
print(nbt.evaluate(test_data))
print(nbt.tag(nltk.word_tokenize(sentence)))
# Out:
# 0.9306806079969019
# [('US', 'PRP'), ('unveils', 'VBZ'), ('world', 'VBN'), ("'s", 'POS'), ('most', 'JJS'), ('powerful', 'JJ'), ('supercomputer', 'NN'), (',', ','), ('beats', 'VBZ'), ('China', 'NNP'), ('.', '.')]

# %%
# try this out for fun!
met = ClassifierBasedPOSTagger(train=train_data,
                               classifier_builder=MaxentClassifier.train)
print(met.evaluate(test_data))
print(met.tag(nltk.word_tokenize(sentence)))
# Out:
#   ==> Training (100 iterations)
#
#       Iteration    Log Likelihood    Accuracy
#       ---------------------------------------
#              1          -3.82864        0.007
#              2          -0.76176        0.957
#       Training stopped: keyboard interrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_55252/1133849022.py in <module>
#       1 # try this out for fun!
# ----> 2 met = ClassifierBasedPOSTagger(train=train_data,
#       3                                classifier_builder=MaxentClassifier.train)
#       4 print(met.evaluate(test_data))
#       5 print(met.tag(nltk.word_tokenize(sentence)))
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/tag/sequential.py in __init__(self, feature_detector, train, classifier_builder, classifier, backoff, cutoff_prob, verbose)
#     640
#     641         if train:
# --> 642             self._train(train, classifier_builder, verbose)
#     643
#     644     def choose_tag(self, tokens, index, history):
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/tag/sequential.py in _train(self, tagged_corpus, classifier_builder, verbose)
#     676         if verbose:
#     677             print(f"Training classifier ({len(classifier_corpus)} instances)")
# --> 678         self._classifier = classifier_builder(classifier_corpus)
#     679
#     680     def __repr__(self):
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/classify/maxent.py in train(cls, train_toks, algorithm, trace, encoding, labels, gaussian_prior_sigma, **cutoffs)
#     323         algorithm = algorithm.lower()
#     324         if algorithm == "iis":
# --> 325             return train_maxent_classifier_with_iis(
#     326                 train_toks, trace, encoding, labels, **cutoffs
#     327             )
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/classify/maxent.py in train_maxent_classifier_with_iis(train_toks, trace, encoding, labels, **cutoffs)
#    1237     if trace > 2:
#    1238         ll = log_likelihood(classifier, train_toks)
# -> 1239         acc = accuracy(classifier, train_toks)
#    1240         print(f"         Final    {ll:14.5f}    {acc:9.3f}")
#    1241
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/classify/util.py in accuracy(classifier, gold)
#      90
#      91 def accuracy(classifier, gold):
# ---> 92     results = classifier.classify_many([fs for (fs, l) in gold])
#      93     correct = [l == r for ((fs, l), r) in zip(gold, results)]
#      94     if correct:
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/classify/api.py in classify_many(self, featuresets)
#      77         :rtype: list(label)
#      78         """
# ---> 79         return [self.classify(fs) for fs in featuresets]
#      80
#      81     def prob_classify_many(self, featuresets):
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/classify/maxent.py in classify(self, featureset)
#     138
#     139     def classify(self, featureset):
# --> 140         return self.prob_classify(featureset).max()
#     141
#     142     def prob_classify(self, featureset):
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/classify/maxent.py in prob_classify(self, featureset)
#     143         prob_dict = {}
#     144         for label in self._encoding.labels():
# --> 145             feature_vector = self._encoding.encode(featureset, label)
#     146
#     147             if self._logarithmic:
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/classify/maxent.py in encode(self, featureset, label)
#     575
#     576             # Otherwise, we might want to fire an "unseen-value feature".
# --> 577             elif self._unseen:
#     578                 # Have we seen this fname/fval combination with any label?
#     579                 for label2 in self._labels:
#
# KeyboardInterrupt:

# %% [markdown]
# # Shallow Parsing or Chunking

# %%
from nltk.corpus import treebank_chunk
data = treebank_chunk.chunked_sents()

train_data = data[:3500]
test_data = data[3500:]
# view sample data
print(train_data[7])
# Out:
# (S
#   (NP A/DT Lorillard/NNP spokewoman/NN)
#   said/VBD
#   ,/,
#   ``/``
#   (NP This/DT)
#   is/VBZ
#   (NP an/DT old/JJ story/NN)
#   ./.)

# %%
from nltk.chunk import RegexpParser

# get POS tagged sentence
tagged_simple_sent = nltk.pos_tag(nltk.word_tokenize(sentence))
print('POS Tags:', tagged_simple_sent)

# illustrate NP chunking based on explicit chunk patterns
chunk_grammar = """
NP: {<DT>?<JJ>*<NN.*>}
"""
rc = RegexpParser(chunk_grammar)
c = rc.parse(tagged_simple_sent)
# Out:
# POS Tags: [('US', 'NNP'), ('unveils', 'JJ'), ('world', 'NN'), ("'s", 'POS'), ('most', 'RBS'), ('powerful', 'JJ'), ('supercomputer', 'NN'), (',', ','), ('beats', 'VBZ'), ('China', 'NNP'), ('.', '.')]

# %%
# print and view chunked sentence using chunking
print(c)
c
# Out:
# (S
#   (NP US/NNP)
#   (NP unveils/JJ world/NN)
#   's/POS
#   most/RBS
#   (NP powerful/JJ supercomputer/NN)
#   ,/,
#   beats/VBZ
#   (NP China/NNP)
#   ./.)
# Tree('S', [Tree('NP', [('US', 'NNP')]), Tree('NP', [('unveils', 'JJ'), ('world', 'NN')]), ("'s", 'POS'), ('most', 'RBS'), Tree('NP', [('powerful', 'JJ'), ('supercomputer', 'NN')]), (',', ','), ('beats', 'VBZ'), Tree('NP', [('China', 'NNP')]), ('.', '.')])

# %%
# illustrate NP chunking based on explicit chink patterns
chink_grammar = """
NP:
    {<.*>+}             # Chunk everything as NP
    }<VBZ|VBD|JJ|IN>+{  # Chink sequences of VBD\VBZ\JJ\IN
"""
rc = RegexpParser(chink_grammar)
c = rc.parse(tagged_simple_sent)

# %%
# print and view chunked sentence using chinking
print(c)
c
# Out:
# (S
#   (NP US/NNP)
#   unveils/JJ
#   (NP world/NN 's/POS most/RBS)
#   powerful/JJ
#   (NP supercomputer/NN ,/,)
#   beats/VBZ
#   (NP China/NNP ./.))
# Tree('S', [Tree('NP', [('US', 'NNP')]), ('unveils', 'JJ'), Tree('NP', [('world', 'NN'), ("'s", 'POS'), ('most', 'RBS')]), ('powerful', 'JJ'), Tree('NP', [('supercomputer', 'NN'), (',', ',')]), ('beats', 'VBZ'), Tree('NP', [('China', 'NNP'), ('.', '.')])])

# %%
# create a more generic shallow parser
grammar = """
NP: {<DT>?<JJ>?<NN.*>}  
ADJP: {<JJ>}
ADVP: {<RB.*>}
PP: {<IN>}      
VP: {<MD>?<VB.*>+}
"""
rc = RegexpParser(grammar)
c = rc.parse(tagged_simple_sent)

# %%
# print and view shallow parsed sample sentence
print(c)
c
# Out:
# (S
#   (NP US/NNP)
#   (NP unveils/JJ world/NN)
#   's/POS
#   (ADVP most/RBS)
#   (NP powerful/JJ supercomputer/NN)
#   ,/,
#   (VP beats/VBZ)
#   (NP China/NNP)
#   ./.)
# Tree('S', [Tree('NP', [('US', 'NNP')]), Tree('NP', [('unveils', 'JJ'), ('world', 'NN')]), ("'s", 'POS'), Tree('ADVP', [('most', 'RBS')]), Tree('NP', [('powerful', 'JJ'), ('supercomputer', 'NN')]), (',', ','), Tree('VP', [('beats', 'VBZ')]), Tree('NP', [('China', 'NNP')]), ('.', '.')])

# %%
# Evaluate parser performance on test data
print(rc.evaluate(test_data))
# Out:
# ChunkParse score:
#     IOB Accuracy:  46.1%%
#     Precision:     19.9%%
#     Recall:        43.3%%
#     F-Measure:     27.3%%

# %%
from nltk.chunk.util import tree2conlltags, conlltags2tree
# look at a sample training tagged sentence
train_sent = train_data[7]
print(train_sent)
# Out:
# (S
#   (NP A/DT Lorillard/NNP spokewoman/NN)
#   said/VBD
#   ,/,
#   ``/``
#   (NP This/DT)
#   is/VBZ
#   (NP an/DT old/JJ story/NN)
#   ./.)

# %%
# get the (word, POS tag, Chunk tag) triples for each token
wtc = tree2conlltags(train_sent)
wtc
# Out:
# [('A', 'DT', 'B-NP'),
#  ('Lorillard', 'NNP', 'I-NP'),
#  ('spokewoman', 'NN', 'I-NP'),
#  ('said', 'VBD', 'O'),
#  (',', ',', 'O'),
#  ('``', '``', 'O'),
#  ('This', 'DT', 'B-NP'),
#  ('is', 'VBZ', 'O'),
#  ('an', 'DT', 'B-NP'),
#  ('old', 'JJ', 'I-NP'),
#  ('story', 'NN', 'I-NP'),
#  ('.', '.', 'O')]

# %%
# get shallow parsed tree back from the WTC triples
tree = conlltags2tree(wtc)
print(tree)
# Out:
# (S
#   (NP A/DT Lorillard/NNP spokewoman/NN)
#   said/VBD
#   ,/,
#   ``/``
#   (NP This/DT)
#   is/VBZ
#   (NP an/DT old/JJ story/NN)
#   ./.)

# %%
def conll_tag_chunks(chunk_sents):
  tagged_sents = [tree2conlltags(tree) for tree in chunk_sents]
  return [[(t, c) for (w, t, c) in sent] for sent in tagged_sents]
  
def combined_tagger(train_data, taggers, backoff=None):
    for tagger in taggers:
        backoff = tagger(train_data, backoff=backoff)
    return backoff

# %%
from nltk.tag import UnigramTagger, BigramTagger
from nltk.chunk import ChunkParserI

class NGramTagChunker(ChunkParserI):
    
  def __init__(self, train_sentences, 
               tagger_classes=[UnigramTagger, BigramTagger]):
    train_sent_tags = conll_tag_chunks(train_sentences)
    self.chunk_tagger = combined_tagger(train_sent_tags, tagger_classes)

  def parse(self, tagged_sentence):
    if not tagged_sentence: 
        return None
    pos_tags = [tag for word, tag in tagged_sentence]
    chunk_pos_tags = self.chunk_tagger.tag(pos_tags)
    chunk_tags = [chunk_tag for (pos_tag, chunk_tag) in chunk_pos_tags]
    wpc_tags = [(word, pos_tag, chunk_tag) for ((word, pos_tag), chunk_tag)
                     in zip(tagged_sentence, chunk_tags)]
    return conlltags2tree(wpc_tags)

# %%
# train the shallow parser
ntc = NGramTagChunker(train_data)

# test parser performance on test data
print(ntc.evaluate(test_data))
# Out:
# ChunkParse score:
#     IOB Accuracy:  97.2%%
#     Precision:     91.4%%
#     Recall:        94.3%%
#     F-Measure:     92.8%%

# %%
# parse our sample sentence
sentence_nlp = nlp(sentence)
tagged_sentence = [(word.text, word.tag_) for word in sentence_nlp]
tree = ntc.parse(tagged_sentence)
print(tree)
tree
# Out:
# (S
#   (NP US/NNP)
#   unveils/VBZ
#   (NP world/NN 's/POS most/RBS powerful/JJ supercomputer/NN)
#   ,/,
#   beats/VBZ
#   (NP China/NNP)
#   ./.)
# Tree('S', [Tree('NP', [('US', 'NNP')]), ('unveils', 'VBZ'), Tree('NP', [('world', 'NN'), ("'s", 'POS'), ('most', 'RBS'), ('powerful', 'JJ'), ('supercomputer', 'NN')]), (',', ','), ('beats', 'VBZ'), Tree('NP', [('China', 'NNP')]), ('.', '.')])

# %%
from nltk.corpus import conll2000
wsj_data = conll2000.chunked_sents()
train_wsj_data = wsj_data[:10000]
test_wsj_data = wsj_data[10000:]
# look at a sample sentence in the corpus
print(train_wsj_data[10])
# Out:
# (S
#   (NP He/PRP)
#   (VP reckons/VBZ)
#   (NP the/DT current/JJ account/NN deficit/NN)
#   (VP will/MD narrow/VB)
#   (PP to/TO)
#   (NP only/RB #/# 1.8/CD billion/CD)
#   (PP in/IN)
#   (NP September/NNP)
#   ./.)

# %%
# train the shallow parser
tc = NGramTagChunker(train_wsj_data)

# test performance on the test data
print(tc.evaluate(test_wsj_data))
# Out:
# ChunkParse score:
#     IOB Accuracy:  89.1%%
#     Precision:     80.3%%
#     Recall:        86.1%%
#     F-Measure:     83.1%%

# %%
# parse our sample sentence
tree = tc.parse(tagged_sentence)
print(tree)
tree
# Out:
# (S
#   (NP US/NNP)
#   (VP unveils/VBZ)
#   (NP world/NN)
#   (NP 's/POS most/RBS powerful/JJ supercomputer/NN)
#   ,/,
#   (VP beats/VBZ)
#   (NP China/NNP)
#   ./.)
# Tree('S', [Tree('NP', [('US', 'NNP')]), Tree('VP', [('unveils', 'VBZ')]), Tree('NP', [('world', 'NN')]), Tree('NP', [("'s", 'POS'), ('most', 'RBS'), ('powerful', 'JJ'), ('supercomputer', 'NN')]), (',', ','), Tree('VP', [('beats', 'VBZ')]), Tree('NP', [('China', 'NNP')]), ('.', '.')])

# %% [markdown]
# # Dependency Parsing

# %%
dependency_pattern = '{left}<---{word}[{w_type}]--->{right}\n--------'
for token in sentence_nlp:
    print(dependency_pattern.format(word=token.orth_, 
                                  w_type=token.dep_,
                                  left=[t.orth_ 
                                            for t 
                                            in token.lefts],
                                  right=[t.orth_ 
                                             for t 
                                             in token.rights]))
# Out:
# []<---US[nsubj]--->[]
# --------
# ['US']<---unveils[ccomp]--->['supercomputer']
# --------
# []<---world[poss]--->["'s"]
# --------
# []<---'s[case]--->[]
# --------
# []<---most[advmod]--->[]
# --------
# ['most']<---powerful[amod]--->[]
# --------
# ['world', 'powerful']<---supercomputer[dobj]--->[]
# --------
# []<---,[punct]--->[]
# --------
# ['unveils', ',']<---beats[ROOT]--->['China', '.']
# --------
# []<---China[dobj]--->[]
# --------
# []<---.[punct]--->[]
# --------

# %%
from spacy import displacy

displacy.render(sentence_nlp, jupyter=True, 
                options={'distance': 110,
                         'arrow_stroke': 2,
                         'arrow_width': 8})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6d57e1b1d3934bea893cfc13b68296db-0" class="displacy" width="1040" height="357.0" direction="ltr" style="max-width: none; height: 357.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">US</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">unveils</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">world</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">powerful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">supercomputer,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">beats</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="267.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">China.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">PROPN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-0" stroke-width="2px" d="M70,222.0 C70,167.0 145.0,167.0 145.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,224.0 L64,214.0 76,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-1" stroke-width="2px" d="M180,222.0 C180,2.0 820.0,2.0 820.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">ccomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,224.0 L174,214.0 186,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-2" stroke-width="2px" d="M290,222.0 C290,112.0 700.0,112.0 700.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M290,224.0 L284,214.0 296,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-3" stroke-width="2px" d="M290,222.0 C290,167.0 365.0,167.0 365.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M365.0,224.0 L371.0,214.0 359.0,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-4" stroke-width="2px" d="M510,222.0 C510,167.0 585.0,167.0 585.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M510,224.0 L504,214.0 516,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-5" stroke-width="2px" d="M620,222.0 C620,167.0 695.0,167.0 695.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M620,224.0 L614,214.0 626,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-6" stroke-width="2px" d="M180,222.0 C180,57.0 705.0,57.0 705.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M705.0,224.0 L711.0,214.0 699.0,214.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6d57e1b1d3934bea893cfc13b68296db-0-7" stroke-width="2px" d="M840,222.0 C840,167.0 915.0,167.0 915.0,222.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6d57e1b1d3934bea893cfc13b68296db-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,224.0 L921.0,214.0 909.0,214.0" fill="currentColor"/>
# </g>
# </svg></span>

# %%
## Deprecated
# from nltk.parse.stanford import StanfordDependencyParser
# sdp = StanfordDependencyParser(path_to_jar='E:/stanford/stanford-parser-full-2015-04-20/stanford-parser.jar',
#                                path_to_models_jar='E:/stanford/stanford-parser-full-2015-04-20/stanford-parser-3.5.2-models.jar')
#
# #perform dependency parsing
# result = list(sdp.raw_parse(sentence))[0]
#
## generate annotated dependency parse tree
# result

# %%
from nltk.parse.corenlp import CoreNLPDependencyParser
sdp = CoreNLPDependencyParser()
result = list(sdp.raw_parse(sentence))[0]
result
# Out:
# <DependencyGraph with 12 nodes>

# %%
# generate dependency triples
[item for item in result.triples()]
# Out:
# [(('unveils', 'VBZ'), 'nsubj', ('US', 'NNP')),
#  (('unveils', 'VBZ'), 'obj', ('supercomputer', 'NN')),
#  (('supercomputer', 'NN'), 'nmod:poss', ('world', 'NN')),
#  (('world', 'NN'), 'case', ("'s", 'POS')),
#  (('supercomputer', 'NN'), 'amod', ('powerful', 'JJ')),
#  (('powerful', 'JJ'), 'advmod', ('most', 'RBS')),
#  (('unveils', 'VBZ'), 'punct', (',', ',')),
#  (('unveils', 'VBZ'), 'dep', ('beats', 'VBZ')),
#  (('beats', 'VBZ'), 'obj', ('China', 'NNP')),
#  (('unveils', 'VBZ'), 'punct', ('.', '.'))]

# %%
# print simple dependency parse tree
dep_tree = result.tree()
print(dep_tree)
# Out:
# (unveils
#   US
#   (supercomputer (world 's) (powerful most))
#   ,
#   (beats China)
#   .)

# %%
# visualize simple dependency parse tree
dep_tree
# Out:
# Tree('unveils', ['US', Tree('supercomputer', [Tree('world', ["'s"]), Tree('powerful', ['most'])]), ',', Tree('beats', ['China']), '.'])

# %% [markdown]
# # Constituency Parsing

# %%
##Deprecated
## set java path
#import os
#java_path = r'C:\Program Files\Java\jdk1.8.0_102\bin\java.exe'
#os.environ['JAVAHOME'] = java_path

# create parser object
#from nltk.parse.stanford import StanfordParser
#scp = StanfordParser(path_to_jar='E:/stanford/stanford-parser-full-2015-04-20/stanford-parser.jar',
                     path_to_models_jar='E:/stanford/stanford-parser-full-2015-04-20/stanford-parser-3.5.2-models.jar')

# get parse tree                   
#result = list(scp.raw_parse(sentence))[0]
# print the constituency parse tree
#print(result)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_55252/1304269739.py in <module>
#       6 # create parser object
#       7 from nltk.parse.stanford import StanfordParser
# ----> 8 scp = StanfordParser(path_to_jar='E:/stanford/stanford-parser-full-2015-04-20/stanford-parser.jar',
#       9                      path_to_models_jar='E:/stanford/stanford-parser-full-2015-04-20/stanford-parser-3.5.2-models.jar')
#      10
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/parse/stanford.py in __init__(self, *args, **kwargs)
#     332         )
#     333
# --> 334         super().__init__(*args, **kwargs)
#     335
#     336     def _make_tree(self, result):
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/parse/stanford.py in __init__(self, path_to_jar, path_to_models_jar, model_path, encoding, verbose, java_options, corenlp_options)
#      47     ):
#      48         # find the most recent code and model jar
# ---> 49         stanford_jar = max(
#      50             find_jar_iter(
#      51                 self._JAR,
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/internals.py in find_jar_iter(name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex)
#     719             yield path_to_jar
#     720         else:
# --> 721             raise LookupError(
#     722                 f"Could not find {name_pattern} jar file at {path_to_jar}"
#     723             )
#
# LookupError: Could not find stanford-parser\.jar jar file at E:/stanford/stanford-parser-full-2015-04-20/stanford-parser.jar

# %%
from nltk.parse.corenlp import CoreNLPParser
scp = CoreNLPParser()

# get parse tree
result = list(scp.raw_parse(sentence))[0]
# print the constituency parse tree
print(result)
# Out:
# (ROOT
#   (SINV
#     (S
#       (NP (NNP US))
#       (VP
#         (VBZ unveils)
#         (NP
#           (NP (NN world) (POS 's))
#           (ADJP (RBS most) (JJ powerful))
#           (NN supercomputer))))
#     (, ,)
#     (VP (VBZ beats))
#     (NP (NNP China))
#     (. .)))

# %%
# visualize the parse tree
from IPython.display import display
display(result)
# Out:
# Tree('ROOT', [Tree('SINV', [Tree('S', [Tree('NP', [Tree('NNP', ['US'])]), Tree('VP', [Tree('VBZ', ['unveils']), Tree('NP', [Tree('NP', [Tree('NN', ['world']), Tree('POS', ["'s"])]), Tree('ADJP', [Tree('RBS', ['most']), Tree('JJ', ['powerful'])]), Tree('NN', ['supercomputer'])])])]), Tree(',', [',']), Tree('VP', [Tree('VBZ', ['beats'])]), Tree('NP', [Tree('NNP', ['China'])]), Tree('.', ['.'])])])

# %%
import nltk
from nltk.grammar import Nonterminal
from nltk.corpus import treebank
# load and view training data
training_set = treebank.parsed_sents()
print(training_set[1])
# Out:
# (S
#   (NP-SBJ (NNP Mr.) (NNP Vinken))
#   (VP
#     (VBZ is)
#     (NP-PRD
#       (NP (NN chairman))
#       (PP
#         (IN of)
#         (NP
#           (NP (NNP Elsevier) (NNP N.V.))
#           (, ,)
#           (NP (DT the) (NNP Dutch) (VBG publishing) (NN group))))))
#   (. .))

# %%
# extract the productions for all annotated training sentences
treebank_productions = list(
                        set(production 
                            for sent in training_set  
                            for production in sent.productions()
                        )
                    )
# view some production rules
treebank_productions[0:10]
# Out:
# [VP -> VBZ ADVP NP-PRD PP,
#  VP -> VBN NP ADVP,
#  NP-SBJ -> DT NNP NNP NNP CD,
#  JJ -> 'low-cost',
#  S -> NP-SBJ=1 PP-CLR=2 , ADVP ADVP=3,
#  VP -> VB PP-CLR NP ADVP-MNR,
#  NN -> 'realization',
#  NNS -> 'arms',
#  CD -> '8.22',
#  JJ -> 'Justice']

# %%
# add productions for each word, POS tag
for word, tag in treebank.tagged_words():
    t = nltk.Tree.fromstring("("+ tag + " " + word  +")")
    for production in t.productions():
        treebank_productions.append(production)

# build the PCFG based grammar  
treebank_grammar = nltk.grammar.induce_pcfg(Nonterminal('S'), 
                                         treebank_productions)

# %%
# build the parser
viterbi_parser = nltk.ViterbiParser(treebank_grammar)

# get sample sentence tokens
tokens = nltk.word_tokenize(sentence)

# get parse tree for sample sentence
result = list(viterbi_parser.parse(tokens))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_55252/3232392445.py in <module>
#       6
#       7 # get parse tree for sample sentence
# ----> 8 result = list(viterbi_parser.parse(tokens))
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/parse/viterbi.py in parse(self, tokens)
#     109
#     110         tokens = list(tokens)
# --> 111         self._grammar.check_coverage(tokens)
#     112
#     113         # The most likely constituent table.  This table specifies the
#
# ~/develop/git/text-analytics-with-python_tohuuu/.venv/lib/python3.12/site-packages/nltk/grammar.py in check_coverage(self, tokens)
#     664         if missing:
#     665             missing = ", ".join(f"{w!r}" for w in missing)
# --> 666             raise ValueError(
#     667                 "Grammar does not cover some of the " "input words: %r." % missing
#     668             )
#
# ValueError: Grammar does not cover some of the input words: "'unveils', 'beats'".

# %%
# get tokens and their POS tags and check it
tagged_sent = nltk.pos_tag(nltk.word_tokenize(sentence))
print(tagged_sent)
# Out:
# [('US', 'NNP'), ('unveils', 'JJ'), ('world', 'NN'), ("'s", 'POS'), ('most', 'RBS'), ('powerful', 'JJ'), ('supercomputer', 'NN'), (',', ','), ('beats', 'VBZ'), ('China', 'NNP'), ('.', '.')]

# %%
# extend productions for sample sentence tokens
for word, tag in tagged_sent:
    t = nltk.Tree.fromstring("("+ tag + " " + word  +")")
    for production in t.productions():
        treebank_productions.append(production)

# rebuild grammar
treebank_grammar = nltk.grammar.induce_pcfg(Nonterminal('S'), 
                                         treebank_productions)                                         
# rebuild parser
viterbi_parser = nltk.ViterbiParser(treebank_grammar)
# get parse tree for sample sentence
result = list(viterbi_parser.parse(tokens))[0]

# print parse tree
print(result)
# Out:
# (S
#   (NP-SBJ-2
#     (NP (NNP US))
#     (NP
#       (NP (JJ unveils) (NN world) (POS 's))
#       (JJS most)
#       (JJ powerful)
#       (NN supercomputer)))
#   (, ,)
#   (VP (VBZ beats) (NP-TTL (NNP China)))
#   (. .)) (p=5.08954e-43)

# %%
# visualize parse tree
result
# Out:
# ProbabilisticTree('S', [ProbabilisticTree('NP-SBJ-2', [ProbabilisticTree('NP', [ProbabilisticTree('NNP', ['US']) (p=0.00025201612903225806)]) (p=1.6913834163238795e-07), ProbabilisticTree('NP', [ProbabilisticTree('NP', [ProbabilisticTree('JJ', ['unveils']) (p=0.00013171759747102212), ProbabilisticTree('NN', ['world']) (p=0.0015174506828528073), ProbabilisticTree('POS', ["'s"]) (p=0.9226118500604595)]) (p=1.2376309059716129e-10), ProbabilisticTree('JJS', ['most']) (p=0.2037914691943128), ProbabilisticTree('JJ', ['powerful']) (p=0.0005268703898840885), ProbabilisticTree('NN', ['supercomputer']) (p=0.00044258978249873547)]) (p=3.947262906727572e-21)]) (p=1.0944811508703948e-29), ProbabilisticTree(',', [',']) (p=0.9995909183882185), ProbabilisticTree('VP', [ProbabilisticTree('VBZ', ['beats']) (p=0.0004088307440719542), ProbabilisticTree('NP-TTL', [ProbabilisticTree('NNP', ['China']) (p=0.0022681451612903227)]) (p=0.00018901209677419354)]) (p=3.6364214664844124e-11), ProbabilisticTree('.', ['.']) (p=0.9876224858174316)]) (p=5.089539274473015e-43)
